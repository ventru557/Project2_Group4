# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

# %%
df = pd.read_csv('loan_clean.csv')
df.head()
# Out:
#    loan_amnt  int_rate  term    dti  annual_inc  delinq_2yrs  open_acc  grade  \
# 0     2400.0      8.90     1  19.14    127000.0          2.0      16.0      1
# 1    16000.0      6.99     1   6.36     80000.0          0.0       7.0      1
# 2    15000.0     13.11     1  11.09    106000.0          0.0      12.0      2
# 3    10500.0     12.12     1  18.62    115000.0          3.0      10.0      2
# 4    12000.0     15.61     1  18.37     65000.0          0.0       7.0      4
#
#    home_ownership  collections_12_mths_ex_med  revol_bal  total_acc  \
# 0               2                         0.0    34227.0       47.0
# 1               1                         0.0    19716.0        8.0
# 2               1                         0.0     7715.0       18.0
# 3               2                         0.0     2662.0       47.0
# 4               2                         0.0     4930.0       21.0
#
#   loan_status
# 0      Normal
# 1      Normal
# 2      Normal
# 3      Normal
# 4      Normal

# %%
def labesencoder(text):
    if text == "Normal":
        return 0
    elif text in ['Default', 'Delinquent', 'Not Compliant']:
        return 1
    else:
        return 2
    
df['loan_status'] = df['loan_status'].apply(labesencoder)

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    33301
# 1     9599
# Name: count, dtype: int64

# %%
X = df.drop('grade', axis=1)
y = df['grade']

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rb = RandomForestClassifier(random_state=42)

rb.fit(X_train, y_train)

y_pred = rb.predict(X_test)

y_prob = rb.predict_proba(X_test)


auc_score = roc_auc_score(y_test, y_prob, multi_class='ovo')

print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("AUC-ROC Score:", auc_score)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98      1750
#            2       0.92      0.93      0.92      3080
#            3       0.81      0.87      0.84      2739
#            4       0.77      0.77      0.77      1848
#            5       0.83      0.69      0.75       880
#            6       0.89      0.80      0.84       323
#            7       0.94      0.64      0.76       105
#
#     accuracy                           0.87     10725
#    macro avg       0.88      0.81      0.84     10725
# weighted avg       0.87      0.87      0.87     10725
#
# Confusion Matrix:
# [[1722   28    0    0    0    0    0]
#  [  41 2854  185    0    0    0    0]
#  [   0  198 2374  167    0    0    0]
#  [   1   11  334 1430   72    0    0]
#  [   2    0   21  238  606   13    0]
#  [   0    0    5   13   42  259    4]
#  [   0    0    0    7   12   19   67]]
# AUC-ROC Score: 0.9681967624058989

# %%
auc_score = roc_auc_score(y_test, y_prob, multi_class='ovo')

# %%
print("AUC-ROC Score:", auc_score)
# Out:
# AUC-ROC Score: 0.9681967624058989

# %%
import zipfile

with zipfile.ZipFile("credit-risk-dataset.zip") as myzip:
    data = myzip.open("loan/loan.csv")

df1 = pd.read_csv(data)
df1.head()
# Out:
# /var/folders/xg/bbnwvbx1417dhq4yrqz43j_h0000gn/T/ipykernel_23412/1923487276.py:6: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(data)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util  \
# 0     10.65       162.87     B        B2  ...          NaN     NaN
# 1     15.27        59.83     C        C4  ...          NaN     NaN
# 2     15.96        84.33     C        C5  ...          NaN     NaN
# 3     13.49       339.31     C        C1  ...          NaN     NaN
# 4     12.69        67.79     B        B5  ...          NaN     NaN
#
#   open_rv_12m  open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi  \
# 0         NaN          NaN        NaN      NaN              NaN    NaN
# 1         NaN          NaN        NaN      NaN              NaN    NaN
# 2         NaN          NaN        NaN      NaN              NaN    NaN
# 3         NaN          NaN        NaN      NaN              NaN    NaN
# 4         NaN          NaN        NaN      NaN              NaN    NaN
#
#   total_cu_tl inq_last_12m
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 74 columns]

# %%
df_sample = df1.sample(frac=0.15)
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133107 entries, 238432 to 394667
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           133107 non-null  int64
#  1   member_id                    133107 non-null  int64
#  2   loan_amnt                    133107 non-null  float64
#  3   funded_amnt                  133107 non-null  float64
#  4   funded_amnt_inv              133107 non-null  float64
#  5   term                         133107 non-null  object
#  6   int_rate                     133107 non-null  float64
#  7   installment                  133107 non-null  float64
#  8   grade                        133107 non-null  object
#  9   sub_grade                    133107 non-null  object
#  10  emp_title                    125437 non-null  object
#  11  emp_length                   126416 non-null  object
#  12  home_ownership               133107 non-null  object
#  13  annual_inc                   133106 non-null  float64
#  14  verification_status          133107 non-null  object
#  15  issue_d                      133107 non-null  object
#  16  loan_status                  133107 non-null  object
#  17  pymnt_plan                   133107 non-null  object
#  18  url                          133107 non-null  object
#  19  desc                         18880 non-null   object
#  20  purpose                      133107 non-null  object
#  21  title                        133082 non-null  object
#  22  zip_code                     133107 non-null  object
#  23  addr_state                   133107 non-null  object
#  24  dti                          133107 non-null  float64
#  25  delinq_2yrs                  133099 non-null  float64
#  26  earliest_cr_line             133099 non-null  object
#  27  inq_last_6mths               133099 non-null  float64
#  28  mths_since_last_delinq       64862 non-null   float64
#  29  mths_since_last_record       20276 non-null   float64
#  30  open_acc                     133099 non-null  float64
#  31  pub_rec                      133099 non-null  float64
#  32  revol_bal                    133107 non-null  float64
#  33  revol_util                   133020 non-null  float64
#  34  total_acc                    133099 non-null  float64
#  35  initial_list_status          133107 non-null  object
#  36  out_prncp                    133107 non-null  float64
#  37  out_prncp_inv                133107 non-null  float64
#  38  total_pymnt                  133107 non-null  float64
#  39  total_pymnt_inv              133107 non-null  float64
#  40  total_rec_prncp              133107 non-null  float64
#  41  total_rec_int                133107 non-null  float64
#  42  total_rec_late_fee           133107 non-null  float64
#  43  recoveries                   133107 non-null  float64
#  44  collection_recovery_fee      133107 non-null  float64
#  45  last_pymnt_d                 130464 non-null  object
#  46  last_pymnt_amnt              133107 non-null  float64
#  47  next_pymnt_d                 95241 non-null   object
#  48  last_credit_pull_d           133097 non-null  object
#  49  collections_12_mths_ex_med   133088 non-null  float64
#  50  mths_since_last_major_derog  33261 non-null   float64
#  51  policy_code                  133107 non-null  float64
#  52  application_type             133107 non-null  object
#  53  annual_inc_joint             61 non-null      float64
#  54  dti_joint                    61 non-null      float64
#  55  verification_status_joint    61 non-null      object
#  56  acc_now_delinq               133099 non-null  float64
#  57  tot_coll_amt                 122710 non-null  float64
#  58  tot_cur_bal                  122710 non-null  float64
#  59  open_acc_6m                  3195 non-null    float64
#  60  open_il_6m                   3195 non-null    float64
#  61  open_il_12m                  3195 non-null    float64
#  62  open_il_24m                  3195 non-null    float64
#  63  mths_since_rcnt_il           3116 non-null    float64
#  64  total_bal_il                 3195 non-null    float64
#  65  il_util                      2760 non-null    float64
#  66  open_rv_12m                  3195 non-null    float64
#  67  open_rv_24m                  3195 non-null    float64
#  68  max_bal_bc                   3195 non-null    float64
#  69  all_util                     3195 non-null    float64
#  70  total_rev_hi_lim             122710 non-null  float64
#  71  inq_fi                       3195 non-null    float64
#  72  total_cu_tl                  3195 non-null    float64
#  73  inq_last_12m                 3195 non-null    float64
# dtypes: float64(49), int64(2), object(23)
# memory usage: 76.2+ MB

# %%
columns = ['loan_amnt', 'int_rate', 'term', 'dti', 'annual_inc', 'delinq_2yrs', 'open_acc',
           'grade', 'home_ownership', 'collections_12_mths_ex_med', 'revol_bal', 'total_acc',
           'loan_status']

df_clean = df_sample[columns]
df_clean.head()
# Out:
#         loan_amnt  int_rate        term    dti  annual_inc  delinq_2yrs  \
# 238432     5000.0     11.99   36 months  13.88     58000.0          0.0
# 35121     12000.0      8.94   36 months  18.99     57000.0          0.0
# 613461     3600.0     16.55   36 months  36.20     56000.0          1.0
# 317582    10000.0     14.99   60 months  15.74     95000.0          1.0
# 448546     4000.0     13.98   36 months  17.97     40130.0          0.0
#
#         open_acc grade home_ownership  collections_12_mths_ex_med  revol_bal  \
# 238432       4.0     B           RENT                         1.0     3548.0
# 35121       13.0     A           RENT                         0.0    25577.0
# 613461      16.0     D           RENT                         0.0    13964.0
# 317582      10.0     C           RENT                         0.0     4731.0
# 448546       5.0     C       MORTGAGE                         0.0     3528.0
#
#         total_acc loan_status
# 238432       10.0     Current
# 35121        26.0  Fully Paid
# 613461       23.0     Current
# 317582       17.0     Current
# 448546       15.0     Current

# %%
def categorize_loan_status(status):
    if status in ['Fully Paid', 'In Grace Period', 'Issued']:
        return 'Normal'
    elif status in ['Late (16-30 days)', 'Late (31-120 days)']:
        return 'Delinquent'
    elif status in ['Charged Off', 'Default']:
        return 'Default'
    elif 'Does not meet the credit policy' in status:
        return 'Not Compliant'
    elif 'Current' in status:
        return 'Current'
    else:
        return 'Unknown'
    
df_clean['loan_status'] = df_clean['loan_status'].apply(categorize_loan_status)
# Out:
# /var/folders/xg/bbnwvbx1417dhq4yrqz43j_h0000gn/T/ipykernel_23412/4248838079.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['loan_status'] = df_clean['loan_status'].apply(categorize_loan_status)

# %%
def apply_label_encoding(column):
    labelencoder = LabelEncoder()
    return labelencoder.fit_transform(column)

columns_to_encode = ['term', 'grade', 'home_ownership']
df_clean[columns_to_encode] = df_clean[columns_to_encode].apply(apply_label_encoding)
df_clean.head()
# Out:
# /var/folders/xg/bbnwvbx1417dhq4yrqz43j_h0000gn/T/ipykernel_23412/790593229.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[columns_to_encode] = df_clean[columns_to_encode].apply(apply_label_encoding)
#         loan_amnt  int_rate  term    dti  annual_inc  delinq_2yrs  open_acc  \
# 238432     5000.0     11.99     0  13.88     58000.0          0.0       4.0
# 35121     12000.0      8.94     0  18.99     57000.0          0.0      13.0
# 613461     3600.0     16.55     0  36.20     56000.0          1.0      16.0
# 317582    10000.0     14.99     1  15.74     95000.0          1.0      10.0
# 448546     4000.0     13.98     0  17.97     40130.0          0.0       5.0
#
#         grade  home_ownership  collections_12_mths_ex_med  revol_bal  \
# 238432      1               4                         1.0     3548.0
# 35121       0               4                         0.0    25577.0
# 613461      3               4                         0.0    13964.0
# 317582      2               4                         0.0     4731.0
# 448546      2               0                         0.0     3528.0
#
#         total_acc loan_status
# 238432       10.0     Current
# 35121        26.0      Normal
# 613461       23.0     Current
# 317582       17.0     Current
# 448546       15.0     Current

# %%
def labesencoder(text):
    if text == "Normal":
        return 0
    elif text in ['Default', 'Delinquent', 'Not Compliant']:
        return 1
    else:
        return 2
    
df_clean['loan_status'] = df_clean['loan_status'].apply(labesencoder)
# Out:
# /var/folders/xg/bbnwvbx1417dhq4yrqz43j_h0000gn/T/ipykernel_23412/811373488.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['loan_status'] = df_clean['loan_status'].apply(labesencoder)

# %%
df_clean.head()
# Out:
#         loan_amnt  int_rate  term    dti  annual_inc  delinq_2yrs  open_acc  \
# 238432     5000.0     11.99     0  13.88     58000.0          0.0       4.0
# 35121     12000.0      8.94     0  18.99     57000.0          0.0      13.0
# 613461     3600.0     16.55     0  36.20     56000.0          1.0      16.0
# 317582    10000.0     14.99     1  15.74     95000.0          1.0      10.0
# 448546     4000.0     13.98     0  17.97     40130.0          0.0       5.0
#
#         grade  home_ownership  collections_12_mths_ex_med  revol_bal  \
# 238432      1               4                         1.0     3548.0
# 35121       0               4                         0.0    25577.0
# 613461      3               4                         0.0    13964.0
# 317582      2               4                         0.0     4731.0
# 448546      2               0                         0.0     3528.0
#
#         total_acc  loan_status
# 238432       10.0            2
# 35121        26.0            0
# 613461       23.0            2
# 317582       17.0            2
# 448546       15.0            2

# %%
import xgboost as xgb

X = df_clean.drop('grade', axis=1)
y = df_clean['grade']

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42)


xgb_model = xgb.XGBClassifier(use_label_encoder=True, n_estimators=500, learning_rate=0.01,
                              subsample=0.8, colsample_bytree=0.8)

# %%
y_train.shape
# Out:
# (32175,)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [21:25:17] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred = xgb_model.predict(X_test)

y_prob = xgb_model.predict_proba(X_test)

auc_score = roc_auc_score(y_test, y_prob, multi_class='ovr')

# Classification Report and Confusion Matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("AUC-ROC Score:", auc_score)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5507
#            1       0.97      0.93      0.95      9539
#            2       0.90      0.92      0.91      9252
#            3       0.85      0.88      0.87      5202
#            4       0.83      0.88      0.85      2686
#            5       0.90      0.83      0.86       861
#            6       0.96      0.83      0.89       230
#
#     accuracy                           0.92     33277
#    macro avg       0.91      0.89      0.90     33277
# weighted avg       0.92      0.92      0.92     33277
#
# Confusion Matrix:
# [[5477   30    0    0    0    0    0]
#  [ 105 8830  604    0    0    0    0]
#  [   1  241 8485  525    0    0    0]
#  [   2    8  266 4586  340    0    0]
#  [   0    0   41  241 2353   51    0]
#  [   1    0    6   19  115  712    8]
#  [   0    0    0    5   11   24  190]]
# AUC-ROC Score: 0.9947846152718519

# %%
from imblearn.over_sampling import RandomOverSampler

oversampler = RandomOverSampler(random_state=42)
X_oversampled, y_oversampled = oversampler.fit_resample(X_train, y_train)

print("After Oversampling:", y_oversampled.value_counts())
# Out:
# After Oversampling: grade
# 0    28610
# 3    28610
# 2    28610
# 1    28610
# 4    28610
# 5    28610
# 6    28610
# Name: count, dtype: int64

# %%
xgb_model_oversampled = xgb_model.fit(X_oversampled, y_oversampled)

y_pred = xgb_model_oversampled.predict(X_test)

y_prob = xgb_model_oversampled.predict_proba(X_test)

auc_score = roc_auc_score(y_test, y_prob, multi_class='ovr')

print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("AUC-ROC Score:", auc_score)
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [21:32:57] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      5507
#            1       0.96      0.89      0.93      9539
#            2       0.90      0.89      0.90      9252
#            3       0.84      0.88      0.86      5202
#            4       0.82      0.92      0.86      2686
#            5       0.91      0.92      0.92       861
#            6       0.94      0.91      0.92       230
#
#     accuracy                           0.91     33277
#    macro avg       0.90      0.92      0.91     33277
# weighted avg       0.91      0.91      0.91     33277
#
# Confusion Matrix:
# [[5477   30    0    0    0    0    0]
#  [ 254 8498  787    0    0    0    0]
#  [   1  277 8274  700    0    0    0]
#  [   2    9  114 4567  509    0    1]
#  [   0    0   19  135 2460   70    2]
#  [   1    0    4   13   37  796   10]
#  [   0    0    0    3   11    7  209]]
# AUC-ROC Score: 0.993949756334379

# %%
from imblearn.under_sampling import RandomUnderSampler

undersampler = RandomUnderSampler(random_state=42)
X_undersampled, y_undersampled = undersampler.fit_resample(X_train, y_train)

print("After Undersampling:", y_undersampled.value_counts())
# Out:
# After Undersampling: grade
# 0    612
# 1    612
# 2    612
# 3    612
# 4    612
# 5    612
# 6    612
# Name: count, dtype: int64

# %%
xgb_model_undersampled = xgb_model.fit(X_undersampled, y_undersampled)

y_pred = xgb_model_undersampled.predict(X_test)

y_prob = xgb_model_undersampled.predict_proba(X_test)

auc_score = roc_auc_score(y_test, y_prob, multi_class='ovr')

print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("AUC-ROC Score:", auc_score)
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [21:34:00] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5507
#            1       0.96      0.91      0.93      9539
#            2       0.89      0.89      0.89      9252
#            3       0.84      0.80      0.82      5202
#            4       0.73      0.91      0.81      2686
#            5       0.88      0.93      0.90       861
#            6       0.88      0.91      0.90       230
#
#     accuracy                           0.90     33277
#    macro avg       0.88      0.90      0.89     33277
# weighted avg       0.90      0.90      0.90     33277
#
# Confusion Matrix:
# [[5477   30    0    0    0    0    0]
#  [  99 8658  782    0    0    0    0]
#  [   1  332 8225  693    1    0    0]
#  [   2   12  195 4148  833    7    5]
#  [   0    0   31  111 2442   93    9]
#  [   1    0    5    9   34  798   14]
#  [   0    0    0    2   13    6  209]]
# AUC-ROC Score: 0.9910451980420839

# %% [markdown]
# Doing Hyper Parameter Tunning

# %%
xgb_model = xgb.XGBClassifier(use_label_encoder=True, n_estimators=400, learning_rate=0.05,
                              subsample=0.8, colsample_bytree=0.8)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [09:47:05] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred = xgb_model.predict(X_test)

y_prob = xgb_model.predict_proba(X_test)

auc_score = roc_auc_score(y_test, y_prob, multi_class='ovr')

# Classification Report and Confusion Matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("AUC-ROC Score:", auc_score)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5507
#            1       0.96      0.94      0.95      9539
#            2       0.91      0.92      0.91      9252
#            3       0.86      0.89      0.88      5202
#            4       0.86      0.87      0.87      2686
#            5       0.88      0.85      0.87       861
#            6       0.96      0.83      0.89       230
#
#     accuracy                           0.93     33277
#    macro avg       0.92      0.90      0.91     33277
# weighted avg       0.93      0.93      0.93     33277
#
# Confusion Matrix:
# [[5468   39    0    0    0    0    0]
#  [  93 8970  476    0    0    0    0]
#  [   1  295 8469  487    0    0    0]
#  [   1   10  278 4633  280    0    0]
#  [   0    0   34  227 2348   77    0]
#  [   1    0    6   21   93  732    8]
#  [   0    0    0    5   11   22  192]]
# AUC-ROC Score: 0.9958448476752462
